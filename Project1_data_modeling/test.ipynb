# %%
# %load_ext sql

# %%
# %sql postgresql://<username>:<pwd>@<ip>/sparkifydb
# Out:
# 'Connected: <name>'

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(483, '1542837407796', 15, 'paid', 'AR5KOSW1187FB35FF4', 'SOZCTXZ12AB0182364', 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')]

# %%
# %sql SELECT * FROM users limit 5;
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
# %sql SELECT * FROM users where first_name='Lily'
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM songs LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM songs where title='Setanta matins'
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('SOZCTXZ12AB0182364', 'Setanta matins', 'AR5KOSW1187FB35FF4', 0, Decimal('269.58322'))]

# %%
# %sql SELECT * FROM artists where artist_id='AR5KOSW1187FB35FF4'
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('AR5KOSW1187FB35FF4', 'Elena', 'Dubai UAE', Decimal('49.80388'), Decimal('15.47491'))]

# %%
# %sql SELECT * FROM artist LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', Decimal('NaN'), Decimal('NaN')),
#  ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', Decimal('35.21962'), Decimal('-80.01955')),
#  ('ARKRRTF1187B9984DA', 'Sonora Santanera', '', Decimal('NaN'), Decimal('NaN')),
#  ('ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', Decimal('NaN'), Decimal('NaN')),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', Decimal('NaN'), Decimal('NaN'))]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('00:03:22.796', 0, '14', 46, 11, 2018, '2'),
#  ('00:06:08.796', 0, '14', 46, 11, 2018, '2'),
#  ('00:11:06.796', 0, '14', 46, 11, 2018, '2'),
#  ('00:17:37.796', 0, '14', 46, 11, 2018, '2'),
#  ('00:20:25.796', 0, '14', 46, 11, 2018, '2')]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql SELECT artist.artist_id, songs.song_id FROM artist JOIN songs ON artist.artist_id = songs.artist_id --WHERE (songs.title = %s AND artists.name = %s AND songs.duration = %s), ('Setanta matins', 'Elena', '269.58322'))
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 146 rows affected.
# [('ARD7TVE1187B99BFB1', 'SOMZWCG12A8C13C480'),
#  ('ARD7TVE1187B99BFB1', 'SOMZWCG12A8C13C480'),
#  ('ARD7TVE1187B99BFB1', 'SOMZWCG12A8C13C480'),
#  ('ARGSJW91187B9B1D6B', 'SOQHXMF12AB0182363'),
#  ('ARGSJW91187B9B1D6B', 'SOQHXMF12AB0182363'),
#  ('ARKRRTF1187B9984DA', 'SOXVLOJ12AB0189215'),
#  ('ARKFYS91187B98E58F', 'SOYMRWW12A6D4FAB14'),
#  ('ARKFYS91187B98E58F', 'SOYMRWW12A6D4FAB14'),
#  ('ARNTLGG11E2835DDB9', 'SOUDSGM12AC9618304'),
#  ('ARNTLGG11E2835DDB9', 'SOUDSGM12AC9618304'),
#  ('AR8ZCNI1187B9A069B', 'SOIAZJW12AB01853F1'),
#  ('AR8ZCNI1187B9A069B', 'SOIAZJW12AB01853F1'),
#  ('ARD0S291187B9B7BF5', 'SOMJBYD12A6D4F8557'),
#  ('AR10USD1187B99F3F1', 'SOHKNRJ12A6701D1F8'),
#  ('AR10USD1187B99F3F1', 'SOHKNRJ12A6701D1F8'),
#  ('ARXR32B1187FB57099', 'SOFSOCN12A8C143F5D'),
#  ('ARXR32B1187FB57099', 'SOFSOCN12A8C143F5D'),
#  ('AR7G5I41187FB4CE6C', 'SONHOTT12A8C13493C'),
# ...
